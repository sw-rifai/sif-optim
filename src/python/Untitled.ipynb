# %%
from dask.distributed import Client
client = Client()
client
# Out:
# /home/sami/miniconda3/envs/sci/lib/python3.8/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40785 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:41953' processes=6 threads=24, memory=125.77 GiB>

# %%
import dask.array as da
x = da.random.random((1000,1000,1000), chunks='16 MiB')
x
# Out:
# dask.array<random_sample, shape=(1000, 1000, 1000), dtype=float64, chunksize=(125, 125, 125), chunktype=numpy.ndarray>

# %%
y = (x + x.T) - x.mean(axis=0)
y.sum().compute()
# Out:
# 500011463.5530191
