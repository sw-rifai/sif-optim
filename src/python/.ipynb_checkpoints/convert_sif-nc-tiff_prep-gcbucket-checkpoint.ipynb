# %% [markdown]
# # Generate an image collection from a stack of netcdfs

# %% [markdown]
# (1) Convert netcdf files to compressed tiffs

# %%
# %%bash
#
# src_path="/media/sami/srifai-ssd/data-ssd/tropomi-conus"
# dst_path="/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif"
# files=`find $src_path -type f -name "*.nc" -printf "%f\n"`
#
#
# # run gdal_translate to convert to tif
# for f in $files
#  do
#     echo $f
#     new_f="${f%.*}.tif"
#     gdal_translate -projwin_srs EPSG:4326 -a_srs EPSG:4326 -of COG -co BLOCKSIZE=512 -co TILING_SCHEME=CUSTOM -co "COMPRESS=DEFLATE" -co "NUM_THREADS=12" netCDF:$src_path/$f:SIF $dst_path/$new_f
# #   gdalwarp -t_srs EPSG:4326 -tr 0.05 0.05 -r average -multi $path/$f /home/sami/scratch/frac_cover/$f &
#  done

# %% [markdown]
# (2) Upload the files to a google cloud storage bucket

# %%
# %%bash
# src_path="/media/sami/srifai-ssd/data-ssd/tropomi-conus"
# files=`find $src_path -type f -name "*.nc" -printf "%f\n"`
#
# for f in $files
#  do
#      new_f="${f%.*}"
#      echo $new_f.tif
#      d="${new_f//[!0-9]/}"
#      date=${d:0:4}-${d:4:2}-${d:6:7}
#      earthengine upload image --asset_id=users/srifai/tropomi-sif/$new_f gs://tropomi-sif-conus/tropomi-sif-tif/$new_f.tif
#      earthengine asset set --time_start $date users/srifai/tropomi-sif/$new_f
#  done
# Out:
# TROPOMI_20180728.tif
# 2018-07-28
# TROPOMI_20190616.tif
# 2019-06-16
# TROPOMI_20180910.tif
# 2018-09-10
# TROPOMI_20180613.tif
# 2018-06-13
# TROPOMI_20180331.tif
# 2018-03-31
# TROPOMI_20180716.tif
# 2018-07-16
# TROPOMI_20180311.tif
# 2018-03-11
# TROPOMI_20190906.tif
# 2019-09-06
# TROPOMI_20190517.tif
# 2019-05-17
# TROPOMI_20190723.tif
# 2019-07-23
# TROPOMI_20190531.tif
# 2019-05-31
# TROPOMI_20190708.tif
# 2019-07-08
# TROPOMI_20200215.tif
# 2020-02-15
# TROPOMI_20190730.tif
# 2019-07-30
# TROPOMI_20181202.tif
# 2018-12-02
# TROPOMI_20181209.tif
# 2018-12-09
# TROPOMI_20200327.tif
# 2020-03-27
# TROPOMI_20180527.tif
# 2018-05-27
# TROPOMI_20190120.tif
# 2019-01-20
# TROPOMI_20190213.tif
# 2019-02-13
# TROPOMI_20180509.tif
# 2018-05-09
# TROPOMI_20180217.tif
# 2018-02-17
# TROPOMI_20190605.tif
# 2019-06-05
# TROPOMI_20190330.tif
# 2019-03-30
# TROPOMI_20200329.tif
# 2020-03-29
# TROPOMI_20180524.tif
# 2018-05-24
# TROPOMI_20200225.tif
# 2020-02-25
# TROPOMI_20200212.tif
# ...

# %%
# %%bash
# fname="TROPOMI_20190124.tif"
#
# earthengine asset set --time_start 2019-01-24 users/srifai/tropomi-sif/"${fname%.*}"

# %%
#  earthengine upload image --asset_id=users/srifai/tropomi-sif/"${fname%.*}" gs://tropomi-sif-conus/tropomi-sif-tif/$fname
#  earthengine asset set --time_start 2019-01-24 users/srifai/tropomi-sif/"${fname%.*}"

# %%
# %%bash
# src_path="/media/sami/srifai-ssd/data-ssd/tropomi-conus"
# dst_path="/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif"
#
# gdal_translate -projwin_srs EPSG:4326 -a_srs EPSG:4326 -of COG -co BLOCKSIZE=512 -co TILING_SCHEME=CUSTOM -co "COMPRESS=DEFLATE" -co "NUM_THREADS=12" netCDF:$src_path/TROPOMI_20180201.nc:SIF $dst_path/test.tif

# %%
# %%bash
# gdalinfo "/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif/test.tif"

# %%
# Error: Projection for test.tif could not be determined. Make sure both CRS and affine transform are present.

# %%
# %%bash
# src_path="/media/sami/srifai-ssd/data-ssd/tropomi-conus"
# dst_path="/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif"
#
# gdal_translate -projwin_srs EPSG:4326 -a_srs EPSG:4326 -of COG -co "GTIFF_WRITE_TOWGS84=YES" -co "COMPRESS=DEFLATE" -co "PREDICTOR=2" -co "NUM_THREADS=12" netCDF:$src_path/TROPOMI_20180201.nc:SIF $dst_path/test2.tif

# %%
# %%bash
# gdalinfo "/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif/test2.tif"

# %%
# %%bash
# gdalinfo "../../../data_general/proc_sif-optim/sif_refgrid.tif"

# %%
# %%bash
# earthengine acl get users/srifai/tropomi-sif

# %%
# %%bash
# fname="TROPOMI_20190124.tif"
# echo "${fname%.*}"

# %%
# %%bash
# src_path="/media/sami/srifai-ssd/data-ssd/tropomi-conus"
#
# files=`find $src_path -type f -name "*.nc" -printf "%f\n"`
#
# # run gdal_translate to convert to tif
# for f in $files
#  do
#     new_f="${f%.*}"
#     echo $new_f
#  done

# %%
gdal_translate -projwin_srs EPSG:4326 -of GTiff -co "COMPRESS=ZSTD" -co "ZSTD_LEVEL=9" -co "NUM_THREADS=12" netCDF:"/media/sami/srifai-ssd/data-ssd/tropomi-conus/TROPOMI_20180201.nc":SIF "/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif/TROPOMI_20180201.tif"

# %%
# %%bash
# gdal_translate -sds -projwin_srs EPSG:4326 -of GTiff -co "TILES=YES" "/media/sami/srifai-ssd/data-ssd/tropomi-conus/TROPOMI_20180201.nc" "/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif/TROPOMI_20180201.tif"

# %%
# %%bash
# # ZSTD_LEVEL=15 is too high, too slow
# gdal_translate -projwin_srs EPSG:4326 -of GTiff -co "COMPRESS=ZSTD" -co "ZSTD_LEVEL=9" -co "NUM_THREADS=12" netCDF:"/media/sami/srifai-ssd/data-ssd/tropomi-conus/TROPOMI_20180201.nc":SIF "/media/sami/srifai-ssd/data-ssd/tropomi-sif-tif/TROPOMI_20180201.tif"
